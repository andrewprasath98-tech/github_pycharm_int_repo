# %% [markdown]
# # **Use Case 1: Banking Eligibility Check**

# %%
age=int(input("Enter the customer age:"))
Monthly_income=int(input("Enter monthly income:"))
if age < 18:
    print("Not eligible for a bank account")
elif age >= 18 and Monthly_income < 15000:
    print("Eligible for basic savings account")
elif age >= 18 and Monthly_income >= 15000 and Monthly_income <= 50000:
    print ("Eligible for savings + salary account")
elif age >= 18 and Monthly_income > 50000:
    print("Eligible for premium account")
# Out:
# Eligible for savings + salary account

# %%
import copy

original = [[1, 2], [3, 4]]

shallow = copy.copy(original)
deep = copy.deepcopy(original)

# %%
number=int(input("Enter the number:"))
if number%2==0:
    print("number is even")
else:
    print("number is odd")
# Out:
# number is even

# %%
import math

radius = float(input("Enter the radius of the circle: "))

area = math.pi * radius ** 2

print("Area of the circle is:", area)
# Out:
# Area of the circle is: 50.26548245743669

# %%
amount=int(input("Enter the amount"))
interest_rate=float(input("Enter the interest_rate:"))
year=float(input("Enter the year:"))
simple_interest=(amount*interest_rate*year)/100
print("simple_interest is:",simple_interest)
# Out:
# simple_interest is: 500.0

# %%
Temperature = float(input("Enter the temperature in Celsius: "))

Fahrenheit = (Temperature * 9 / 5) + 32

print("Fahrenheit is:", Fahrenheit)
# Out:
# Fahrenheit is: 86.0

# %%
# Ask the user to enter 5 marks separated by spaces (e.g., 85 90 78 92 88)
marks = list(map(float, input("Enter 5 subject marks: ").split()))

totalmarks = sum(marks)
percentage = (totalmarks / 500) * 100

print("Total marks:", totalmarks)
print("Percentage:", percentage, "%")
# Out:
# Total marks: 290.0
# Percentage: 57.99999999999999 %

# %%
Age=int(input("Enter the age:"))
Citizen=input(" Are you a Citizen of India? yes or no:")

if Age>=18 and Citizen=="yes":
    print("you are eligible for vote")
elif Age>=18 and Citizen=="no":
    print("you are not Indian citizen not eligible for vote")
elif  Age<18 and Citizen=="yes":
    print("you are under age not eligible for vote")
else:
    print("your not eligible for vote")
# Out:
# your not eligible for vote

# %%
price=int(input("Enter the amount:"))
Discount=float(input("Enter the Discount %:"))
Discount_amount=price*Discount/100
Final_price=price-Discount_amount
print("Discount amount:",Discount_amount)
print("final_price:",Final_price)
# Out:
# Discount amount: 400.0
# final_price: 19600.0

# %%
text="hello"
reversed="".join(reversed(text))
print(reversed)
# Out:
# olleh

# %%
text = "madam"

if text == text[::-1]:
    print("It is a palindrome")
else:
    print("It is not a palindrome")
# Out:
# It is a palindrome
